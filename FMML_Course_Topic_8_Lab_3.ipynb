# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswi123803/Tejaswi/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 05:09:08--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   201MB/s    in 0.3s
#
# 2024-03-31 05:09:09 (201 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3142    1406.4465v2  Multi-task feature learning aims to identity t...    cs
# 22180  1506.08002v1  Taking into account high-order interactions am...  stat
# 35986   0903.0200v1  Since the Turing test was first proposed by Al...    cs
# 20224  1504.07168v1  This paper addresses two classes of different,...    cs
# 20898  1705.00303v2  In this paper we show how the defense relation...    cs
# ...             ...                                                ...   ...
# 5201    1111.6925v1  Probabilistic graphical models combine the gra...  stat
# 29945  1711.02144v3  In this paper, we address the problem of road ...    cs
# 24383   1311.2621v1  Analysis of microscopy images is one important...    cs
# 1009   1509.07385v3  We discuss approximation of functions using de...  stat
# 9741   1802.05622v1  Geostatistical modeling of petrophysical prope...  stat
#
#                                                    title  year  \
# 3142   Multi-stage Multi-task feature learning via ad...  2014
# 22180  Safe Feature Pruning for Sparse High-Order Int...  2015
# 35986  Faith in the Algorithm, Part 1: Beyond the Tur...  2009
# 20224  Further Connections Between Contract-Schedulin...  2015
# 20898  Defense semantics of argumentation: encoding r...  2017
# ...                                                  ...   ...
# 5201   Structure Learning of Probabilistic Graphical ...  2011
# 29945  A Joint 3D-2D based Method for Free Space Dete...  2017
# 24383  Determining Leishmania Infection Levels by Aut...  2013
# 1009   Provable approximation properties for deep neu...  2015
# 9741   Conditioning of three-dimensional generative a...  2018
#
#                                                 keywords
# 3142   [generalization, minimizing, alternatives, the...
# 22180  [interactions, covariates, practical, regressi...
# 35986  [artificial, intelligence, predicated, compute...
# 20224  [addresses, different, interrelated, optimizat...
# 20898  [arguments, accepting, arguments, introducing,...
# ...                                                  ...
# 5201   [probabilistic, graphical, probability, multiv...
# 29945  [segmentation, detection, autonomous, traditio...
# 24383  [microscopy, important, biomedical, quantifica...
# 1009   [approximation, functions, dimensional, constr...
# 9741   [geostatistical, petrophysical, properties, in...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3142     [generalization, minimizing, alternatives, the...
# 22180    [interactions, covariates, practical, regressi...
# 35986    [artificial, intelligence, predicated, compute...
# 20224    [addresses, different, interrelated, optimizat...
# 20898    [arguments, accepting, arguments, introducing,...
#                                ...
# 34671    [nationality, identification, important, demog...
# 1013     [recurrent, recognized, potential, determined,...
# 21545    [formulate, consistency, empirical, minimisati...
# 9029     [techniques, inductively, collections, introdu...
# 20015    [extension, semantics, associated, justificati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8886 words.
# Out of those 4530 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bf5fa17e-5847-470a-a371-07ebb78a7e73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf5fa17e-5847-470a-a371-07ebb78a7e73")) {                    Plotly.newPlot(                        "bf5fa17e-5847-470a-a371-07ebb78a7e73",                        [{"x":["minimizing","generalization","regularized","empirical","algorithm","detection","performance","adaptively","synthetic","effectiveness","determine","therefore","selection","prescribed","corresponding","regularization","adaptivity","previously","incorporate","iterative","component","efficient","demonstrate","alternatives","presented","additional","formulation","harnesses","suboptimal","particular","threshold","definition","computationally","challenging","considered","introduce","interaction","covariates","descendant","structure","satisfies","guaranteed","specifically","screening","computational","practical","satisfied","condition","extremely","dramatically","infeasible","underlying","interactions","regression","sufficiently","abilities","contribute","artificial","predicated","advancement","demonstrated","computers","amplification","intelligence","contribution","concurrent","different","connections","strategies","addresses","objective","redundancy","searching","randomized","scheduling","algorithms","probabilistic","motivated","considerations","addressed","environment","tolerance","optimization","equivalence","arguments","argumentation","respectively","accepting","summarization","introducing","semantics","outperforms","conflicts","execution","introduces","consistently","parallelizing","asynchronous","implementation","reduction","implementations","framework","mechanisms","stochastic","practitioners","development","industrial","prediction","conducted","underestimation","evaluation","alternative","estimation","financial","competitive","situations","comparison","challenge","traditional","estimated","theoretical","inconsistent","constrained","eigenvector","incomplete","formulate","achieving","information","integrates","favorably","comparisons","semidefinite","aggregation","relaxation","guarantees","simulations","numerical","synchronization","extensive","establishing","available","applications","instantiations","consistent","procedure","programming","remaining","rotations","supervised","statistical","usefulness","literature","approximated","technique","transformed","typically","continuous","comprises","generative","determining","correspondences","distances","optimizing","nonlinear","distribution","distributions","transformation","iteration","variables","furthermore","transforming","geometric","transforms","integrate","incrementally","localization","feasibility","localizing","experiments","providing","observation","potential","augmented","heterogeneous","simultaneously","practicality","computing","deformable","benefiting","promising","explanation","penalized","stagewise","multilingual","discusses","electronic","disambiguation","contemporary","construction","integrating"],"y":[49,113,52,151,875,367,855,23,149,224,73,140,154,7,128,97,4,108,54,86,101,370,569,25,175,142,72,2,16,284,47,47,89,272,126,304,76,2,0,346,16,39,167,15,278,130,17,52,46,25,11,137,62,124,24,16,27,129,2,6,106,23,5,90,73,7,695,51,92,59,163,20,34,31,17,609,148,58,11,33,133,7,329,23,21,13,85,2,32,55,107,268,4,34,81,43,2,13,136,107,40,567,51,156,21,120,19,236,73,1,262,103,220,11,97,47,134,151,168,67,162,14,74,3,28,50,75,708,23,23,31,5,25,18,69,45,86,10,173,15,276,461,5,69,99,131,21,7,221,164,33,110,23,258,25,123,121,14,120,36,18,38,38,53,217,121,67,46,147,156,13,90,29,50,14,69,29,8,610,88,62,147,34,38,114,6,137,11,3,119,19,9,1,25,24,30,18,14,61,28],"type":"bar"},{"x":["minimizing","generalization","regularized","emp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4530,), (4530, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.785

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Cloud</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.8769230769230769);'>Evolutionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style=''>study</span> <br/><br/><span style=''>After</span> <span style=''>a</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>concept</span> <span style=''>using</span> <span style=''>Dropbox(tm)</span> <span style=''>a</span> <span style=''>free</span> <span style=''>storage</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>synchronization</span> <span style=''>service</span> <span style=''>showed</span> <span style=''>that</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.8769230769230769);'>evolutionary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>dissimilar</span> <span style='background-color:rgba(0, 255, 0, 0.7037037037037037);'>computers</span> <span style='background-color:rgba(0, 255, 0, 0.46666666666666656);'>connected</span> <span style=''>via</span> <span style=''>WiFi</span> <span style=''>or</span> <span style=''>Ethernet</span> <span style=''>had</span> <span style=''>a</span> <span style=''>good</span> <span style=''>scaling</span> <span style=''>behavior</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluations</span> <span style=''>per</span> <span style=''>second</span> <span style=''>it</span> <span style=''>remains</span> <span style=''>to</span> <span style=''>be</span> <span style=''>proved</span> <span style=''>whether</span> <span style=''>that</span> <span style=''>effect</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>translates</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>will</span> <span style=''>check</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>problems</span> <span style=''>and</span> <span style=''>see</span> <span style=''>what</span> <span style=''>effects</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4771784232365146);'>automatic</span> <span style=''>load</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>balancing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>asynchrony</span> <span style=''>have</span> <span style=''>on</span> <span style=''>the</span> <span style=''>speed</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.676056338028169);'>resolution</span> <span style=''>of</span> <span style=''>problems</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Lost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relatives</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Gumbel</span> <span style=''>Trick</span> <br/><br/><span style=''>The</span> <span style=''>Gumbel</span> <span style=''>trick</span> <span style=''>is</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>a</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>or</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partition</span> <span style=''>function</span> <span style=''>The</span> <span style=''>method</span> <span style=''>relies</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>repeatedly</span> <span style=''>applying</span> <span style=''>a</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbation</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>way</span> <span style=''>each</span> <span style=''>time</span> <span style=''>solving</span> <span style=''>for</span> <span style=''>the</span> <span style=''>most</span> <span style=''>likely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>configuration</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>an</span> <span style=''>entire</span> <span style=''>family</span> <span style=''>of</span> <span style=''>related</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>which</span> <span style=''>the</span> <span style=''>Gumbel</span> <span style=''>trick</span> <span style=''>is</span> <span style=''>one</span> <span style=''>member</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>new</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>superior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>in</span> <span style=''>several</span> <span style=''>settings</span> <span style=''>with</span> <span style=''>minimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Gumbel</span> <span style=''>trick</span> <span style=''>to</span> <span style=''>yield</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>benefits</span> <span style=''>for</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>Gumbel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbations</span> <span style=''>on</span> <span style=''>all</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>configurations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>replaced</span> <span style=''>with</span> <span style=''>so</span> <span style=''>called</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perturbations</span> <span style=''>We</span> <span style=''>show</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Quantified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantage</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>discontinuous</span> <span style=''>weight</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.4042553191489362);'>approximations</span> <span style=''>with</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.4042553191489362);'>approximations</span> <span style=''>of</span> <span style=''>1D</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>by</span> <span style=''>deep</span> <span style=''>ReLU</span> <span style=''>networks</span> <span style=''>of</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>width</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>without</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>weight</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>the</span> <span style=''>uniform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>error</span> <span style=''>is</span> <span style=''>lower</span> <span style=''>than</span> <span style=''>with</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>at</span> <span style=''>least</span> <span style=''>by</span> <span style=''>a</span> <span style=''>factor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>logarithmic</span> <span style=''>in</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sequence</span> <span style=''>Modeling</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Segmentations</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Segmental</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>a</span> <span style=''>common</span> <span style=''>pattern</span> <span style=''>in</span> <span style=''>many</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>such</span> <span style=''>as</span> <span style=''>phrases</span> <span style=''>in</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>languages</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>via</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentations</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmented</span> <span style=''>sequence</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>as</span> <span style=''>the</span> <span style=''>product</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>all</span> <span style=''>its</span> <span style=''>segments</span> <span style=''>where</span> <span style=''>each</span> <span style=''>segment</span> <span style=''>is</span> <span style=''>modeled</span> <span style=''>using</span> <span style=''>existing</span> <span style=''>tools</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Since</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>is</span> <span style=''>usually</span> <span style=''>unknown</span> <span style=''>in</span> <span style=''>advance</span> <span style=''>we</span> <span style=''>sum</span> <span style=''>over</span> <span style=''>all</span> <span style=''>valid</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentations</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>the</span> <span style=''>final</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>for</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>forward</span> <span style=''>and</span> <span style=''>backward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resorting</span> <span style=''>to</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>We</span> <span style='background-color:rgba ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	translation (0.04614838480653177)
# 	different (0.24671636492722754)
# 	architecture (0.08448704295349663)
# 	experimental (0.1402200922967696)
# 	representation (0.14093006744763933)
# 	segmentation (0.07880724174653887)
# 	information (0.25133120340788073)
# 	detection (0.13028044018459353)
# 	recognition (0.1306354277600284)
# 	convolutional (0.13454029108981186)
#
# Some Statistics words are:
# 	stochastic (0.14120020171457387)
# 	theoretical (0.14523449319213314)
# 	statistical (0.14624306606152296)
# 	algorithm (0.39989914271306104)
# 	variables (0.1422087745839637)
# 	estimation (0.1714573877962683)
# 	distribution (0.17750882501260717)
# 	inference (0.1880988401412002)
# 	dimensional (0.18305597579425115)
# 	regression (0.18204740292486132)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="515a3c63-b824-4db5-9db0-2065f99290ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("515a3c63-b824-4db5-9db0-2065f99290ac")) {                    Plotly.newPlot(                        "515a3c63-b824-4db5-9db0-2065f99290ac",                        [{"x":["minimizing","generalization","regularized","empirical","algorithm","detection","performance","adaptively","synthetic","effectiveness","determine","therefore","selection","prescribed","corresponding","regularization","adaptivity","previously","incorporate","iterative","component","efficient","demonstrate","alternatives","presented","additional","formulation","harnesses","suboptimal","particular","threshold","definition","computationally","challenging","considered","introduce","interaction","covariates","descendant","structure","satisfies","guaranteed","specifically","screening","computational","practical","satisfied","condition","extremely","dramatically","infeasible","underlying","interactions","regression","sufficiently","abilities","contribute","artificial","predicated","advancement","demonstrated","computers","amplification","intelligence","contribution","concurrent","different","connections","strategies","addresses","objective","redundancy","searching","randomized","scheduling","algorithms","probabilistic","motivated","considerations","addressed","environment","tolerance","optimization","equivalence","arguments","argumentation","respectively","accepting","summarization","introducing","semantics","outperforms","conflicts","execution","introduces","consistently","parallelizing","asynchronous","implementation","reduction","implementations","framework","mechanisms","stochastic","practitioners","development","industrial","prediction","conducted","underestimation","evaluation","alternative","estimation","financial","competitive","situations","comparison","challenge","traditional","estimated","theoretical","inconsistent","constrained","eigenvector","incomplete","formulate","achieving","information","integrates","favorably","comparisons","semidefinite","aggregation","relaxation","guarantees","simulations","numerical","synchronization","extensive","establishing","available","applications","instantiations","consistent","procedure","programming","remaining","rotations","supervised","statistical","usefulness","literature","approximated","technique","transformed","typically","continuous","comprises","generative","determining","correspondences","distances","optimizing","nonlinear","distribution","distributions","transformation","iteration","variables","furthermore","transforming","geometric","transforms","integrate","incrementally","localization","feasibility","localizing","experiments","providing","observation","potential","augmented","heterogeneous","simultaneously","practicality","computing","deformable","benefiting","promising","explanation","penalized","stagewise","multilingual","discusses","electronic","disambiguation","contemporary","construction","integrating","processing","comprehensive","communication","automatic","resources","automatically","constructed","evaluates","inventory","disambiguate","adversely","conducting","annotations","collected","incorrectly","effectively","unsatisfactory","attention","consuming","intensive","baselines","including","expensive","discriminative","suppresses","annotating","increases","recognition","application","recognizing","components","extractors","classification","convolutional","limitations","orientation","benchmark","estimating","measurement","constructing","heuristic","generated","currently","formulated","dimension","established","approximately","chervonenkis","illustrate","compressed","measurements","probability","developed","char ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	descendant
# 	submanifold
# 	subsample
# 	timestamps
# 	martingales
# 	specialist
# 	sparsifies
# 	pessimistic
# 	specializes
# 	homoscedastic
# 	heteroscedastic
# 	propensity
# 	misspecified
# 	newtonian
# 	newsvendor
# 	intermittent
# 	asymptotics
# 	movielens
# 	retrospective
# 	omnipresent
# Some words which never appear in Statistics papers:
# 	predicated
# 	amplification
# 	argumentation
# 	localizing
# 	disambiguate
# 	annotating
# 	satisfiability
# 	deficiencies
# 	propagators
# 	investment
# 	propagator
# 	unannotated
# 	dialogues
# 	lexicographical
# 	precedence
# 	orientations
# 	imperfect
# 	intentions
# 	rectification
# 	homography

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0581039755351684e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.73
